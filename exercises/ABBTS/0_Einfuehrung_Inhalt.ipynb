# %% [markdown]
# <a href="http://www.abbts.ch" target="_blank"><img src="img/ABBTS_Logo.jpg" width="30%"/></a>

# %% [markdown]
# # Python Grundlagen (PYT_G01)
# In dieser Zusammenfassung werden diejenigen Punkte der Programmiersprache Python behandelt, welche innerhalb des Unterrichts im Modul *Python Grundlagen* verwendet werden. Selbstverständlich darf diese Zusammenfassung persönlich angepasst und erweitert werden. <br>
# Der Inhalt orientiert sich stark am folgenden Buch:
# - Einführung in Python 3, Klein Bernd, Hanser, 3. Auflage (https://www.python-kurs.eu/python3_kurs.php)
#
# Sie finden darin auch kapitelbezogene Aufgaben, inkl. Lösungen.
#
# Zusatzliteratur:
# - Programmieren lernen mit Python, Downey Allen B., O'REILLY, 2. Auflage
# - Tutorials
# - Cheat-Sheets

# %% [markdown]
# ## Inhalt
# 1. <a href="1_Variablen.ipynb" target="_blank">Variablen</a>
# 2. <a href="2_0_Datentypen.ipynb" target="_blank">Datentypen</a>
# 3. <a href="3_Eingaben.ipynb" target="_blank">Eingaben</a>
# 4. <a href="4_Kontrollstrukturen.ipynb" target="_blank">Kontrollstrukturen</a>
# 5. <a href="5_Dateien_lesen_schreiben.ipynb" target="_blank">Dateien lesen und schreiben</a>
# 6. <a href="6_Funktionen.ipynb" target="_blank">Funktionen</a>
# 7. <a href="7_1_Objektorientierte_Programmierung.ipynb" target="_blank">Objektorientierte Programmierung</a>
# 7. <a href="8_1_Threads.ipynb" target="_blank">Threads</a>

# %% [markdown]
# Wie aus dem Inhalt ersichtlich, fokussiert der erste Teil (1-6) des Faches die prozedurale Programmierung. Der Aspekt der Objektorientiertheit wird danach eingeführt.

# %% [markdown]
# ---

# %%
# END
